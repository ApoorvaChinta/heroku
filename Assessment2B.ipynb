# %% [markdown]
# <a href="https://colab.research.google.com/github/ApoorvaChinta/heroku/blob/main/Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
college_1=pd.read_csv('/content/drive/MyDrive/Task4/college_1.csv')
c1=pd.DataFrame(college_1)
college_2=pd.read_csv('/content/drive/MyDrive/Task4/college_2.csv')
index=pd.Series([i for i in range(1,120)])
c2=pd.DataFrame(college_2)
a=pd.concat([c1,c2])
a.set_index(index,inplace=True)
data=a.to_csv('data.csv')
data=pd.read_csv('data.csv',index_col=[0])
data
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 1        A.Dharani    82.0   20.0              24500           24500
# 2      V.JEEVITHA     82.0   20.0              21740           21740
# 3      HEMAVATHI.R   100.0  100.0              19680           19680
# 4      Mugunthan S   100.0   47.0              10610           10610
# 5      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 115  praveen raj j    24.0    0.0               2380            2380
# 116     AMARNATH D    -1.0   12.0               1890            1890
# 117           bala    32.0    0.0               1720            1720
# 118           XY Z    -1.0   -1.0                  0               0
# 119      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 1             Computer Science and Engineering       0        NaN
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
reached=data.loc[(data['CodeKata Score']>10000) & (data['CodeKata Score']>15000)]
reached.to_csv('reached_expectation.csv')
r=pd.read_csv('reached_expectation.csv',index_col=[0])
needs=data.loc[(data['CodeKata Score']>7000) & (data['CodeKata Score']>10000)]
needs.to_csv('needs_improvement.csv')
n=pd.read_csv('needs_improvement.csv',index_col=[0])
unsatisfactory=data.loc[(data['CodeKata Score']<7000)]
unsatisfactory.to_csv('unsatisfactory.csv')
u=pd.read_csv('unsatisfactory.csv',index_col=[0])
u
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 9         J.SUGANTHI    27.0  50.00               5860            5860
# 10      thamizhpaana    29.0   0.00               5500            5500
# 11   Iyappan Samiraj    50.0  24.00               5400            5400
# 12      Ponniyamma.R   100.0  11.25               5380            5380
# 13         SABAPATHI   100.0   0.00               5280            5280
# ..               ...     ...    ...                ...             ...
# 115    praveen raj j    24.0   0.00               2380            2380
# 116       AMARNATH D    -1.0  12.00               1890            1890
# 117             bala    32.0   0.00               1720            1720
# 118             XY Z    -1.0  -1.00                  0               0
# 119        Hariharan    -1.0  -1.00                  0               0
#
#                                     Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
average=[]
for i in range(1,(len(data['CodeKata Score']))+1):
  average.append(int(((data['CodeKata Score'])[i]+(data['Previous Geekions'])[i])/2))
data['Average']=average
data
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 1        A.Dharani    82.0   20.0              24500           24500
# 2      V.JEEVITHA     82.0   20.0              21740           21740
# 3      HEMAVATHI.R   100.0  100.0              19680           19680
# 4      Mugunthan S   100.0   47.0              10610           10610
# 5      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 115  praveen raj j    24.0    0.0               2380            2380
# 116     AMARNATH D    -1.0   12.0               1890            1890
# 117           bala    32.0    0.0               1720            1720
# 118           XY Z    -1.0   -1.0                  0               0
# 119      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 1             Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### No of students participated

# %%
len(data['Name'])
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
data[0:3]
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 1    A.Dharani    82.0   20.0              24500           24500
# 2  V.JEEVITHA     82.0   20.0              21740           21740
# 3  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  \
# 1  Computer Science and Engineering       0        NaN
# 2  Computer Science and Engineering       0        NaN
# 3  Computer Science and Engineering       0        NaN
#
#    computational_thinking  Average
# 1                     NaN    24500
# 2                     NaN    21740
# 3                     NaN    19680

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
(data.sort_values(by='Previous Geekions',ascending=False))[0:3]
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 1    A.Dharani    82.0   20.0              24500           24500
# 2  V.JEEVITHA     82.0   20.0              21740           21740
# 3  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  \
# 1  Computer Science and Engineering       0        NaN
# 2  Computer Science and Engineering       0        NaN
# 3  Computer Science and Engineering       0        NaN
#
#    computational_thinking  Average
# 1                     NaN    24500
# 2                     NaN    21740
# 3                     NaN    19680

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
fi=px.pie(data,values='CodeKata Score',names='Department',color_discrete_sequence =['#de425b','#ef805b','#f7b672'])
fi
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
for (department), dw in data.groupby(['Department']):
  dw.to_csv(f'{department}.csv',index=False)
comp=pd.read_csv('Computer Science and Engineering.csv')
ece=pd.read_csv('Electronics and Communication Engineering.csv')
eee=pd.read_csv('Electronics and Electrical Engineering.csv')

# %%
q=comp.sort_values(by='CodeKata Score',ascending=False)
fig1=px.bar(x=q['CodeKata Score'],y=q['Name'],color=q['Name'], title='Computer Science Department')
fig1.add_annotation(x=24500,y='A.Dharani',showarrow=True,arrowhead=3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2=px.bar(x=ece['CodeKata Score'],y=ece['Name'],color=ece['Name'])
fig2.add_annotation(x=10040,y='Gowtham R',text='Topper',arrowhead=3,showarrow=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig3=px.bar(x=eee['CodeKata Score'],y=eee['Name'],color=eee['Name'])
fig3.add_annotation(x=19400,y='ASHOK KUMAR K',text='Topper(Electronics and Electrical Engineering)',arrowhead=3,showarrow=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.bar(x=data['CodeKata Score'],y=data['Name'],color=data['Department'])
fig.add_annotation(x=24500,y='A.Dharani',text='Topper(Computer Science and Engineering)',arrowhead=3,showarrow=True)
fig.add_annotation(x=10040,y='Bodipudi Harini',text='Topper',arrowhead=3,showarrow=True)
fig.add_annotation(x=19400,y='ASHOK KUMAR K',text='Topper(Electronics and Electrical Engineering)',arrowhead=3,showarrow=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
